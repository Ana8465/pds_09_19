# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
url = 'https://raw.githubusercontent.com/PulockDas/pd-12-resources/refs/heads/master/titanic.csv'
titanic = pd.read_csv(url)

# %% [markdown]
# **2.Feature names with null values**

# %%
null_columns = titanic.columns[titanic.isnull().any()]
print("Columns with null values:", null_columns.tolist())
# Out:
# Columns with null values: ['Age', 'Cabin', 'Embarked']

# %% [markdown]
# **3.Filling Missing Values**

# %%
titanic['Age'].fillna(titanic['Age'].mean())
#df.method({Age: mean()}, inplace=True)

# Fill missing 'Cabin' values with 'Unknown'
titanic['Cabin'].fillna('Unknown')
# Out:
# 0      Unknown
# 1          C85
# 2      Unknown
# 3         C123
# 4      Unknown
#         ...
# 886    Unknown
# 887        B42
# 888    Unknown
# 889       C148
# 890    Unknown
# Name: Cabin, Length: 891, dtype: object

# %% [markdown]
# **4.Plotting Dtaset with Two  Bars**

# %%
titanic['Survival Status'] = titanic['Survived'].map({0: 'Dead', 1: 'Survived'})

# Plot the data
plt.figure(figsize=(10, 6))
sns.countplot(data=titanic, x='Survival Status', hue='Sex', palette=['#1f77b4', '#ff7f0e'])
plt.title('Survival Count by Gender')
plt.xlabel('Survival Status')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **5.Survival Counter By Passenger class**

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=titanic, x='Survival Status', hue='Pclass', palette='viridis')
plt.title('Survival Count by Passenger Class')
plt.xlabel('Survival Status')
plt.ylabel('Count')
plt.legend(title='Passenger Class')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=titanic, x='Survival Status', hue='Pclass', palette='viridis')
plt.title('Survival Count by Passenger Class')
plt.xlabel('Survival Status')
plt.ylabel('Count')
plt.legend(title='Passenger Class')
plt.show()

# %% [markdown]
# **6.Create a column named 'AgeClass' and insert value**

# %%
bins = [0, 16, 26, 36, 62, float('inf')]
labels = [0, 1, 2, 3, 4]

# Create 'AgeClass' column
titanic['AgeClass'] = pd.cut(titanic['Age'], bins=bins, labels=labels, right=False)

# %% [markdown]
# **Drop the column 'Age'**

# %%
titanic.drop('Age', axis=1, inplace=True)
#print(titanic.columns)
#if 'Age' in titanic.columns:
    ''''titanic.drop('Age', axis=1, inplace=True)
    print(titanic.columns)
else:
    print("'Age' column has already been dropped or does not exist.")''''
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked', 'Survival Status', 'AgeClass'],
#       dtype='object')
# 'Age' column has already been dropped or does not exist.

# %% [markdown]
# ***Create a bar plot of Survived and Dead using the value counts amongst 'AgeClass'
# groups t**

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=titanic, x='Survival Status', hue='AgeClass', palette='coolwarm')
plt.title('Survival Count by Age Class')
plt.xlabel('Survival Status')
plt.ylabel('Count')
plt.legend(title='Age Class')
plt.show()
